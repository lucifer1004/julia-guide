# %% [markdown]
# ---
# title: "使用 Plots.jl 绘图"
# lang: zh
# jupyter: julia-1.8
# ---

# %%
#| code-fold: true
#| code-summary: "本节运行环境配置"
#| output: false

import Pkg; Pkg.activate("..")
using Plots
# Out:
#   Activating project at `~/com.github/lucifer1004/julia-guide`

# %%
#| label: plots-basic-plot
#| fig-cap: "使用 Plots.jl 绘制折线图（后端为 GR）"

plot(1:10, rand(10))
