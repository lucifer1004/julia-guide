# %% [markdown]
# ---
# title: "使用 Makie.jl 绘图"
# lang: zh
# jupyter: julia-1.8
# ---

# %%
#| code-fold: true
#| code-summary: "本节运行环境配置"
#| output: false

import Pkg; Pkg.activate("..")
using CairoMakie
CairoMakie.activate!(type="svg")
# Out:
#   Activating project at `~/com.github/lucifer1004/julia-guide`

# %%
#| label: cairo-makie-basic-plot
#| fig-cap: "使用 Makie.jl 绘制折线图（后端为 Cairo）"

lines(1:10, rand(10))
